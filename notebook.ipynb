# %%
# -------------------------------------------------------------------------
# You can also run a Jupyter Notebook file,
# Which provides a useful environment for testing certain functionalities
# -------------------------------------------------------------------------

# To run this file in Visual Studio Code, ensure you have:
# - dev dependencies: ipykernel, ipywidgets, nbformat
# - extension: Jupyter

# %%
from app.lib.api.yahoofinance import yahoofinance

ticker_data = yahoofinance("BTC-USD", "2025-12-01")

ticker_data.tail(3)

# %%
from app.database.methods import db

# %%
df = db.ohlc.get_all(ticker="BTC-USD", interval="h1", return_dataframe=True)
df.tail()
