# %%
# -------------------------------------------------------------------------
# You can also run a Jupyter Notebook file,
# Which provides a useful environment for testing certain functionalities
# -------------------------------------------------------------------------

# To run this file in Visual Studio Code, ensure you have:
# - dev dependencies: ipykernel, ipywidgets, nbformat
# - extension: Jupyter

# %%
from app.lib.utils import Providers

ticker_data = Providers.yahoofinance("BTC-USD", "2025-12-01")

ticker_data.tail(3)
# Out:
# Price               open          high           low         close  \
# date
# 2025-12-15  88171.078125  89983.921875  85304.078125  86419.781250
# 2025-12-16  86424.406250  88170.093750  85381.687500  87843.984375
# 2025-12-17  87842.867188  90194.296875  85345.039062  85836.914062
#
# Price            volume       date
# date
# 2025-12-15  45559514323 2025-12-15
# 2025-12-16  41262178223 2025-12-16
# 2025-12-17  43860439040 2025-12-17
